# %% [markdown]
# ### SellOut: Información de venta al consumidor final.

# %%
import pandas as pd
import numpy as np

# %%
# Importo el Dataframe en formato Excel
df_sellout = pd.read_excel("SellOut.xlsx")

# %%
# Observo el Dataframe con el que voy a trabajar. 
df_sellout
# Out:
#        Año      Fecha                      Nombre Categoría  \
# 0     2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# 1     2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# 2     2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# 3     2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# 4     2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# ...    ...        ...                                   ...
# 4852  2021 2021-03-31                   TINTES Y COLORACION
# 4853  2021 2021-03-31                   TINTES Y COLORACION
# 4854  2021 2021-03-31                   TINTES Y COLORACION
# 4855  2021 2021-03-31                   TINTES Y COLORACION
# 4856  2021 2021-03-31                   TINTES Y COLORACION
#
#                                  Nombre Subcategoria  \
# 0     ACONDICIONADOR CREMA Y TRATAMIENTOS COSMETICOS
# 1     ACONDICIONADOR CREMA Y TRATAMIENTOS COSMETICOS
# 2     ACONDICIONADOR CREMA Y TRATAMIENTOS COSMETICOS
# ...

# %%
# Observo las primeras filas del DataFrame
df_sellout.head()
# Out:
#     Año      Fecha                      Nombre Categoría  \
# 0  2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# 1  2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# 2  2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# 3  2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
# 4  2020 2020-02-01  SHAMPOO ACONDICIONADOR Y TRATAMIENTO
#
#                               Nombre Subcategoria      Nombre SubCategoria 2  \
# 0  ACONDICIONADOR CREMA Y TRATAMIENTOS COSMETICOS  ACONDICIONADOR IL SALONE.
# 1  ACONDICIONADOR CREMA Y TRATAMIENTOS COSMETICOS  ACONDICIONADOR IL SALONE.
# 2  ACONDICIONADOR CREMA Y TRATAMIENTOS COSMETICOS  ACONDICIONADOR IL SALONE.
# 3  ACONDICIONADOR CREMA Y TRATAMIENTOS COSMETICOS  ACONDICIONADOR IL SALONE.
# 4  ACONDICIONADOR CREMA Y TRATAMIENTOS COSMETICOS  ACONDICIONADOR IL SALONE.
#
#    Código Producto                                    Nombre Producto  \
# 0        100147247               ACONDICIONADOR IL SALONE EPIC 500 ML
# ...

# %%
# Puedo ver una tupla con el número de filas y columnas del DataFrame
df_sellout.shape
# Out:
# (4857, 13)

# %%
# Observo el tipo de datos que tiene el DataFrame
df_sellout.dtypes
# Out:
# Año                                        int64
# Fecha                             datetime64[ns]
# Nombre Categoría                          object
# Nombre Subcategoria                       object
# Nombre SubCategoria 2                     object
# Código Producto                            int64
# Nombre Producto                           object
# Nombre Corto Unidad de Negocio            object
# Código Local                               int64
# Nombre Local                              object
# Cantidad Items                             int64
# Venta Neta                               float64
# Costo Total de Venta                     float64
# dtype: object

# %%
# Con el comando info() me hago una idea con los campos que voy a trabajar
df_sellout.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4857 entries, 0 to 4856
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Año                             4857 non-null   int64
#  1   Fecha                           4857 non-null   datetime64[ns]
#  2   Nombre Categoría                4857 non-null   object
#  3   Nombre Subcategoria             4857 non-null   object
#  4   Nombre SubCategoria 2           4857 non-null   object
#  5   Código Producto                 4857 non-null   int64
#  6   Nombre Producto                 4857 non-null   object
#  7   Nombre Corto Unidad de Negocio  4857 non-null   object
#  8   Código Local                    4857 non-null   int64
#  9   Nombre Local                    4857 non-null   object
#  10  Cantidad Items                  4857 non-null   int64
#  11  Venta Neta                      4857 non-null   float64
# ...

# %%
# Creo una variable para saber si existen valores nulos en el dataframe 
valores_nulos = df_sellout.isnull()
valores_nulos
# Out:
#         Año  Fecha  Nombre Categoría  Nombre Subcategoria  \
# 0     False  False             False                False
# 1     False  False             False                False
# 2     False  False             False                False
# 3     False  False             False                False
# 4     False  False             False                False
# ...     ...    ...               ...                  ...
# 4852  False  False             False                False
# 4853  False  False             False                False
# 4854  False  False             False                False
# 4855  False  False             False                False
# 4856  False  False             False                False
#
#       Nombre SubCategoria 2  Código Producto  Nombre Producto  \
# 0                     False            False            False
# 1                     False            False            False
# 2                     False            False            False
# ...

# %%
# Observo que no existen valores nulos en todo el dataframe
valores_nulos.sum()
# Out:
# Año                               0
# Fecha                             0
# Nombre Categoría                  0
# Nombre Subcategoria               0
# Nombre SubCategoria 2             0
# Código Producto                   0
# Nombre Producto                   0
# Nombre Corto Unidad de Negocio    0
# Código Local                      0
# Nombre Local                      0
# Cantidad Items                    0
# Venta Neta                        0
# Costo Total de Venta              0
# dtype: int64

# %%
# con any() verifico si hay filas duplicadas en el DataFrame
hay_duplicados = df_sellout.duplicated().any()

if hay_duplicados:
    print("Existen filas duplicadas en el DataFrame.")
else:
    print("No hay filas duplicadas en el DataFrame.")
# Out:
# No hay filas duplicadas en el DataFrame.
